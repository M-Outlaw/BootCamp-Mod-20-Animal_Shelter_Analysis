# %%
from sqlalchemy import create_engine
import psycopg2
import pandas as pd

from config import db_password

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/acc_data"

# %%
engine = create_engine(db_string)

# %%
df = pd.read_csv("Resources/Austin_Animal_Center_Intakes.csv")
df
# Out:
#        Animal ID     Name                DateTime               MonthYear  \
# 0        A786884   *Brock  01/03/2019 04:19:00 PM  01/03/2019 04:19:00 PM
# 1        A706918    Belle  07/05/2015 12:59:00 PM  07/05/2015 12:59:00 PM
# 2        A724273  Runster  04/14/2016 06:43:00 PM  04/14/2016 06:43:00 PM
# 3        A665644      NaN  10/21/2013 07:59:00 AM  10/21/2013 07:59:00 AM
# 4        A682524      Rio  06/29/2014 10:38:00 AM  06/29/2014 10:38:00 AM
# ...          ...      ...                     ...                     ...
# 135703   A850185      NaN  01/19/2022 05:40:00 PM  01/19/2022 05:40:00 PM
# 135704   A849503   Indigo  01/19/2022 05:10:00 PM  01/19/2022 05:10:00 PM
# 135705   A850189      NaN  01/19/2022 05:40:00 PM  01/19/2022 05:40:00 PM
# 135706   A850191      NaN  01/19/2022 05:40:00 PM  01/19/2022 05:40:00 PM
# 135707   A850186      NaN  01/19/2022 05:40:00 PM  01/19/2022 05:40:00 PM
#
#                                     Found Location      Intake Type  \
# ...

# %%
df = pd.read_csv("Resources/Austin_Animal_Center_Intakes.csv")
df.to_sql(name='intakes', con=engine)

# %%
df = pd.read_csv("Resources/Austin_Animal_Center_Outcomes.csv")
df
# Out:
#        Animal ID     Name                DateTime               MonthYear  \
# 0        A794011    Chunk  05/08/2019 06:20:00 PM  05/08/2019 06:20:00 PM
# 1        A776359    Gizmo  07/18/2018 04:02:00 PM  07/18/2018 04:02:00 PM
# 2        A821648      NaN  08/16/2020 11:38:00 AM  08/16/2020 11:38:00 AM
# 3        A720371    Moose  02/13/2016 05:59:00 PM  02/13/2016 05:59:00 PM
# 4        A674754      NaN  03/18/2014 11:47:00 AM  03/18/2014 11:47:00 AM
# ...          ...      ...                     ...                     ...
# 135969   A849858      NaN  01/19/2022 05:45:00 PM  01/19/2022 05:45:00 PM
# 135970   A850191      NaN  01/19/2022 05:47:00 PM  01/19/2022 05:47:00 PM
# 135971   A850187      NaN  01/19/2022 05:45:00 PM  01/19/2022 05:45:00 PM
# 135972   A849645      NaN  01/19/2022 05:37:00 PM  01/19/2022 05:37:00 PM
# 135973   A849786  A849786  01/19/2022 05:19:00 PM  01/19/2022 05:19:00 PM
#
#        Date of Birth Outcome Type Outcome Subtype Animal Type  \
# ...

# %%
df = pd.read_csv("Resources/Austin_Animal_Center_Outcomes.csv")
df.to_sql(name='outcomes', con=engine)

# %%
df = pd.read_csv("Resources/merged_AKC.csv")
df
# Out:
#        Unnamed: 0 Animal ID    Name  \
# 0               0   A006100   Scamp
# 1               1   A006100   Scamp
# 2               2   A006100   Scamp
# 3               3   A047759    Oreo
# 4               4   A134067  Bandit
# ...           ...       ...     ...
# 75986       75986   A850187     NaN
# 75987       75987   A850188     NaN
# 75988       75988   A850189     NaN
# 75989       75989   A850190     NaN
# 75990       75990   A850191     NaN
#
#                                       Found Location      Intake Type  \
# 0                       8700 Research in Austin (TX)    Public Assist
# 1                  8700 Research Blvd in Austin (TX)    Public Assist
# 2      Colony Creek And Hunters Trace in Austin (TX)            Stray
# 3                                        Austin (TX)  Owner Surrender
# 4                 12034 Research Blvd in Austin (TX)    Public Assist
# ...                                              ...              ...
# ...

# %%
df = pd.read_csv("Resources/merged_AKC.csv")
df.to_sql(name='merged_AKC', con=engine)

# %%
df = pd.read_csv("Resources/BreedInfo.csv")
df
# Out:
#                             Breed              Austin_breedname     AKC_group  \
# 0                   Affenpinscher                 Affenpinscher           toy
# 1                    Afghan Hound                  Afghan Hound         hound
# 2                Airedale Terrier              Airedale Terrier       terrier
# 3                           Akita                         Akita       working
# 4              Alaskan Eskimo Dog                     Klee Klai  non-sporting
# ..                            ...                           ...           ...
# 232               Spanish Mastiff               Spanish Mastiff       working
# 233             Spanish Water Dog             Spanish Water Dog       herding
# 234  Grand Basset Griffon Vendeen  Grand Basset Griffon Vendeen         hound
# 235              Alaskan Klee Kai              Alaskan Klee Kai       working
# 236                      Hovawart                      Hovawart       working
#
#     size_cat
# 0      small
# ...

# %%
df = pd.read_csv("Resources/Austin_Animal_Center_Outcomes.csv")
df.to_sql(name='breedinfo', con=engine)
