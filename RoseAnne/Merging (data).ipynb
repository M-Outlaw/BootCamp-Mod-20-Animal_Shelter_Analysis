# %%
import pandas as pd
df1 = pd.read_csv("Resources/Austin_Animal_Center_Intakes.csv")
df2 = pd.read_csv("Resources/Austin_Animal_Center_Outcomes.csv")
df = pd.merge(df1,df2,on='Animal ID', how ='inner')

# %%
pd.merge(df1,df2,left_on='Animal ID',right_on='Animal ID',how='left')
# Out:
#        Animal ID   Name_x              DateTime_x             MonthYear_x  \
# 0        A786884   *Brock  01/03/2019 04:19:00 PM  01/03/2019 04:19:00 PM
# 1        A706918    Belle  07/05/2015 12:59:00 PM  07/05/2015 12:59:00 PM
# 2        A724273  Runster  04/14/2016 06:43:00 PM  04/14/2016 06:43:00 PM
# 3        A665644      NaN  10/21/2013 07:59:00 AM  10/21/2013 07:59:00 AM
# 4        A682524      Rio  06/29/2014 10:38:00 AM  06/29/2014 10:38:00 AM
# ...          ...      ...                     ...                     ...
# 175720   A850185      NaN  01/19/2022 05:40:00 PM  01/19/2022 05:40:00 PM
# 175721   A849503   Indigo  01/19/2022 05:10:00 PM  01/19/2022 05:10:00 PM
# 175722   A850189      NaN  01/19/2022 05:40:00 PM  01/19/2022 05:40:00 PM
# 175723   A850191      NaN  01/19/2022 05:40:00 PM  01/19/2022 05:40:00 PM
# 175724   A850186      NaN  01/19/2022 05:40:00 PM  01/19/2022 05:40:00 PM
#
#                                     Found Location      Intake Type  \
# ...

# %%
df.to_csv('Austin_Animal_Center merged.csv')
