# %%
#Dependencies
import pandas as pd

# %%
intake_df=pd.read_csv("Austin_Animal_Center_Intakes.csv")
intake_df.head()
# Out:
#   Animal ID     Name                DateTime               MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  01/03/2019 04:19:00 PM
# 1   A706918    Belle  07/05/2015 12:59:00 PM  07/05/2015 12:59:00 PM
# 2   A724273  Runster  04/14/2016 06:43:00 PM  04/14/2016 06:43:00 PM
# 3   A665644      NaN  10/21/2013 07:59:00 AM  10/21/2013 07:59:00 AM
# 4   A682524      Rio  06/29/2014 10:38:00 AM  06/29/2014 10:38:00 AM
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# ...

# %%
print(intake_df.dtypes)
print(len(intake_df))
# Out:
# Animal ID           object
# Name                object
# DateTime            object
# MonthYear           object
# Found Location      object
# Intake Type         object
# Intake Condition    object
# Animal Type         object
# Sex upon Intake     object
# Age upon Intake     object
# Breed               object
# Color               object
# dtype: object
# 135662

# %%
outcome_df=pd.read_csv("Austin_Animal_Center_Outcomes.csv")
outcome_df.head()
# Out:
#   Animal ID   Name                DateTime               MonthYear  \
# 0   A794011  Chunk  05/08/2019 06:20:00 PM  05/08/2019 06:20:00 PM
# 1   A776359  Gizmo  07/18/2018 04:02:00 PM  07/18/2018 04:02:00 PM
# 2   A821648    NaN  08/16/2020 11:38:00 AM  08/16/2020 11:38:00 AM
# 3   A720371  Moose  02/13/2016 05:59:00 PM  02/13/2016 05:59:00 PM
# 4   A674754    NaN  03/18/2014 11:47:00 AM  03/18/2014 11:47:00 AM
#
#   Date of Birth Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0    05/02/2017    Rto-Adopt             NaN         Cat    Neutered Male
# 1    07/12/2017     Adoption             NaN         Dog    Neutered Male
# 2    08/16/2019   Euthanasia             NaN       Other          Unknown
# 3    10/08/2015     Adoption             NaN         Dog    Neutered Male
# 4    03/12/2014     Transfer         Partner         Cat      Intact Male
#
#   Age upon Outcome                               Breed              Color
# ...

# %%
The dataset we plan to use includes 76000 encounters involving dogs at the Austin Animal Center (Austin, TX) from 2013 through the present. 
Data is publicly available through the Austin open data portal. Data is available on [intakes](https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Intakes/wter-evkm) and [outcomes](https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Outcomes/9t4d-g238). 
Possible outcomes include:
-adoption
-return to owner
-euthanasia
-transfer

Intake fields include:
-date of encounter
-type of encounter
-Sex 
-Age
-Breed
-Color

Additional features can be extracted/estimated from these fields, including:
-spay/neuter status

# %%
print(outcome_df.dtypes)
print(len(outcome_df))
# Out:
# Animal ID           object
# Name                object
# DateTime            object
# MonthYear           object
# Date of Birth       object
# Outcome Type        object
# Outcome Subtype     object
# Animal Type         object
# Sex upon Outcome    object
# Age upon Outcome    object
# Breed               object
# Color               object
# dtype: object
# 135927

# %%
from collections import Counter
Counter(outcome_df["Outcome Type"])
# Out:
# Counter({'Rto-Adopt': 835,
#          'Adoption': 62035,
#          'Euthanasia': 8943,
#          'Transfer': 39441,
#          'Return to Owner': 22649,
#          'Died': 1283,
#          'Disposal': 621,
#          'Missing': 72,
#          'Relocate': 25,
#          nan: 23})

# %%
breeds=Counter(outcome_df["Breed"])
print(len(breeds))
breeds
# Out:
# 2724
# Counter({'Domestic Shorthair Mix': 32325,
#          'Chihuahua Shorthair Mix': 6477,
#          'Raccoon': 491,
#          'Anatol Shepherd/Labrador Retriever': 33,
#          'American Foxhound/Labrador Retriever': 2,
#          'Border Collie/Cardigan Welsh Corgi': 3,
#          'Pit Bull': 1761,
#          'Domestic Shorthair': 10143,
#          'Domestic Medium Hair Mix': 3248,
#          'Domestic Medium Hair': 1058,
#          'Opossum': 155,
#          'Yorkshire Terrier Mix': 642,
#          'Jack Russell Terrier/Chihuahua Shorthair': 69,
#          'Great Pyrenees Mix': 609,
#          'Bat Mix': 1756,
#          'Chihuahua Shorthair': 1296,
#          'Australian Cattle Dog Mix': 1631,
#          'Beagle Mix': 621,
#          'Labrador Retriever Mix': 7333,
#          'Labrador Retriever/Staffordshire': 12,
#          'Pit Bull Mix': 8879,
#          'German Shepherd Mix': 3269,
#          'Dogo Argentino Mix': 28,
#          'Black Mouth Cur Mix': 415,
# ...

# %%
data_df=pd.merge(intake_df, outcome_df, on="Animal ID")
data_df.head()
# Out:
#   Animal ID   Name_x              DateTime_x             MonthYear_x  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  01/03/2019 04:19:00 PM
# 1   A706918    Belle  07/05/2015 12:59:00 PM  07/05/2015 12:59:00 PM
# 2   A724273  Runster  04/14/2016 06:43:00 PM  04/14/2016 06:43:00 PM
# 3   A665644      NaN  10/21/2013 07:59:00 AM  10/21/2013 07:59:00 AM
# 4   A682524      Rio  06/29/2014 10:38:00 AM  06/29/2014 10:38:00 AM
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type_x Sex upon Intake Age upon Intake  ...              DateTime_y  \
# ...

# %%
print(len(data_df))
print(data_df.isnull().sum())
# Out:
# 175132
# Animal ID                0
# Name_x               41634
# DateTime_x               0
# MonthYear_x              0
# Found Location           0
# Intake Type              0
# Intake Condition         0
# Animal Type_x            0
# Sex upon Intake          1
# Age upon Intake          0
# Breed_x                  0
# Color_x                  0
# Name_y               41634
# DateTime_y               0
# MonthYear_y              0
# Date of Birth            0
# Outcome Type            34
# Outcome Subtype     106917
# Animal Type_y            0
# Sex upon Outcome         1
# Age upon Outcome         4
# Breed_y                  0
# Color_y                  0
# dtype: int64

# %%
duplicates=data_df[data_df.duplicated()]
duplicates
# Out:
#        Animal ID    Name_x              DateTime_x             MonthYear_x  \
# 7251     A830075    Waffle  03/02/2021 01:35:00 PM  03/02/2021 01:35:00 PM
# 7252     A830075    Waffle  03/02/2021 01:35:00 PM  03/02/2021 01:35:00 PM
# 14855    A696688      Mari  02/10/2015 11:00:00 AM  02/10/2015 11:00:00 AM
# 14857    A696688      Mari  02/10/2015 11:00:00 AM  02/10/2015 11:00:00 AM
# 14858    A696688      Mari  02/10/2015 11:00:00 AM  02/10/2015 11:00:00 AM
# ...          ...       ...                     ...                     ...
# 170091   A783234  Princess  11/01/2018 02:36:00 PM  11/01/2018 02:36:00 PM
# 170092   A783234  Princess  11/01/2018 02:36:00 PM  11/01/2018 02:36:00 PM
# 173021   A846569   A846569  11/17/2021 02:58:00 PM  11/17/2021 02:58:00 PM
# 173022   A846569   A846569  11/17/2021 02:58:00 PM  11/17/2021 02:58:00 PM
# 173023   A846569   A846569  11/17/2021 02:58:00 PM  11/17/2021 02:58:00 PM
#
# ...

# %%
outcomes = data_df["Outcome Type"]
outcome_set=set(outcomes)
outcome_set
# Out:
# 175132

# %%
from collections import Counter

# %%
Counter(outcomes)
# Out:
# Counter({'Transfer': 43046,
#          'Return to Owner': 37973,
#          'Adoption': 81145,
#          'Euthanasia': 9301,
#          'Disposal': 629,
#          'Died': 1321,
#          'Rto-Adopt': 1561,
#          'Missing': 98,
#          nan: 34,
#          'Relocate': 24})

# %%
Counter({'Rto-Adopt': 835,
         'Adoption': 62035,
         'Euthanasia': 8943,
         'Transfer': 39441,
         'Return to Owner': 22649,
         'Died': 1283,
         'Disposal': 621,
         'Missing': 72,
         'Relocate': 25,
         nan: 23})

# %%
Counter(outcome_df["Animal Type"])
# Out:
# Counter({'Cat': 51730,
#          'Dog': 76350,
#          'Other': 7191,
#          'Bird': 631,
#          'Livestock': 25})

# %%
Counter(intake_df["Animal Type"])
# Out:
# Counter({'Dog': 76334,
#          'Cat': 51481,
#          'Other': 7192,
#          'Bird': 631,
#          'Livestock': 24})

# %%
Counter(outcome_df["Outcome Subtype"])
# Out:
# Counter({nan: 73768,
#          'Partner': 33092,
#          'Foster': 12230,
#          'SCRP': 3211,
#          'Out State': 254,
#          'Suffering': 3443,
#          'Underage': 36,
#          'Snr': 2870,
#          'Rabies Risk': 3952,
#          'In Kennel': 667,
#          'Offsite': 445,
#          'Aggressive': 565,
#          'Enroute': 89,
#          'At Vet': 292,
#          'In Foster': 326,
#          'Behavior': 158,
#          'Medical': 324,
#          'Field': 75,
#          'Possible Theft': 16,
#          'Barn': 12,
#          'Customer S': 17,
#          'Court/Investigation': 36,
#          'Emer': 5,
#          'In Surgery': 27,
#          'Prc': 11,
#          'Emergency': 5,
#          'In State': 1})
