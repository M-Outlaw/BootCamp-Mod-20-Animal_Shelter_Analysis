# %%
#Dependencies
import pandas as pd
from collections import Counter

# %%
intake_df=pd.read_csv("Austin_Animal_Center_Intakes.csv")

print(intake_df.dtypes)
print(len(intake_df))
intake_df.head()
# Out:
# Animal ID           object
# Name                object
# DateTime            object
# MonthYear           object
# Found Location      object
# Intake Type         object
# Intake Condition    object
# Animal Type         object
# Sex upon Intake     object
# Age upon Intake     object
# Breed               object
# Color               object
# dtype: object
# 135662
#   Animal ID     Name                DateTime               MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  01/03/2019 04:19:00 PM
# 1   A706918    Belle  07/05/2015 12:59:00 PM  07/05/2015 12:59:00 PM
# 2   A724273  Runster  04/14/2016 06:43:00 PM  04/14/2016 06:43:00 PM
# 3   A665644      NaN  10/21/2013 07:59:00 AM  10/21/2013 07:59:00 AM
# 4   A682524      Rio  06/29/2014 10:38:00 AM  06/29/2014 10:38:00 AM
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# ...

# %%
outcome_df=pd.read_csv("Austin_Animal_Center_Outcomes.csv")
print(outcome_df.dtypes)
print(len(outcome_df))
outcome_df.head()
# Out:
# Animal ID           object
# Name                object
# DateTime            object
# MonthYear           object
# Date of Birth       object
# Outcome Type        object
# Outcome Subtype     object
# Animal Type         object
# Sex upon Outcome    object
# Age upon Outcome    object
# Breed               object
# Color               object
# dtype: object
# 135927
#   Animal ID   Name                DateTime               MonthYear  \
# 0   A794011  Chunk  05/08/2019 06:20:00 PM  05/08/2019 06:20:00 PM
# 1   A776359  Gizmo  07/18/2018 04:02:00 PM  07/18/2018 04:02:00 PM
# 2   A821648    NaN  08/16/2020 11:38:00 AM  08/16/2020 11:38:00 AM
# 3   A720371  Moose  02/13/2016 05:59:00 PM  02/13/2016 05:59:00 PM
# 4   A674754    NaN  03/18/2014 11:47:00 AM  03/18/2014 11:47:00 AM
#
#   Date of Birth Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0    05/02/2017    Rto-Adopt             NaN         Cat    Neutered Male
# ...

# %%
#Keep dogs
dogs_intake=intake_df[intake_df["Animal Type"]=="Dog"]
print(len(dogs_intake))
dogs_intake.head()
# Out:
# 76324
#   Animal ID     Name                DateTime               MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  01/03/2019 04:19:00 PM
# 1   A706918    Belle  07/05/2015 12:59:00 PM  07/05/2015 12:59:00 PM
# 2   A724273  Runster  04/14/2016 06:43:00 PM  04/14/2016 06:43:00 PM
# 4   A682524      Rio  06/29/2014 10:38:00 AM  06/29/2014 10:38:00 AM
# 5   A743852     Odin  02/18/2017 12:46:00 PM  02/18/2017 12:46:00 PM
#
#                         Found Location      Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)            Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)            Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)            Stray           Normal
# 4        800 Grove Blvd in Austin (TX)            Stray           Normal
# 5                          Austin (TX)  Owner Surrender           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# ...

# %%
#Drop full duplicate rows
intake_df=intake_df.drop_duplicates()
len(intake_df)
# Out:
# 135642

# %%
# Out:
#        Animal ID     Name                DateTime               MonthYear  \
# 589      A731435   *Casey  07/22/2016 10:44:00 AM  07/22/2016 10:44:00 AM
# 1508     A732478   Cowboy  08/12/2016 12:40:00 PM  08/12/2016 12:40:00 PM
# 2104     A670462   *Tomas  01/08/2014 03:04:00 PM  01/08/2014 03:04:00 PM
# 2618     A801583    Molly  01/18/2020 02:28:00 PM  01/18/2020 02:28:00 PM
# 2657     A730944     King  08/18/2016 06:04:00 PM  08/18/2016 06:04:00 PM
# ...          ...      ...                     ...                     ...
# 135650   A844202      NaN  01/18/2022 05:15:00 PM  01/18/2022 05:15:00 PM
# 135653   A849202  *Paulie  01/18/2022 05:15:00 PM  01/18/2022 05:15:00 PM
# 135655   A825862    Tater  11/14/2020 08:36:00 AM  11/14/2020 08:36:00 AM
# 135656   A825862    Tater  12/22/2021 10:22:00 AM  12/22/2021 10:22:00 AM
# 135657   A844937    Carti  12/28/2021 11:46:00 AM  12/28/2021 11:46:00 AM
#
#                                            Found Location      Intake Type  \
# ...

# %%
#Dogs with multiple records
Counter(multiples["Animal ID"])
# Out:
# Counter({'A731435': 1,
#          'A732478': 2,
#          'A670462': 1,
#          'A801583': 2,
#          'A730944': 1,
#          'A810189': 3,
#          'A416147': 4,
#          'A754715': 2,
#          'A754607': 1,
#          'A658843': 2,
#          'A716018': 8,
#          'A769150': 3,
#          'A664439': 1,
#          'A721876': 2,
#          'A677045': 1,
#          'A665874': 2,
#          'A736912': 1,
#          'A607663': 2,
#          'A784947': 1,
#          'A686092': 1,
#          'A757624': 1,
#          'A765485': 1,
#          'A665219': 1,
#          'A808587': 4,
#          'A775323': 1,
#          'A691584': 2,
#          'A819429': 2,
#          'A655441': 1,
#          'A825138': 3,
#          'A711583': 2,
#          'A820074': 1,
#          'A839354': 2,
#          'A686386': 2,
#          'A483604': 1,
#          'A693171': 1,
#          'A714665': 1,
#          'A840093': 1,
#          'A727923': 2,
#          'A670785': 2,
#          'A751778': 1,
# ...

# %%
print(intake_df.loc[intake_df["Animal ID"]=="A721033"])
# Out:
#        Animal ID     Name                DateTime               MonthYear  \
# 4070     A721033  Lil Bit  02/24/2019 09:53:00 PM  02/24/2019 09:53:00 PM
# 10584    A721033  Lil Bit  03/07/2018 08:27:00 AM  03/07/2018 08:27:00 AM
# 12761    A721033  Lil Bit  05/20/2019 10:18:00 AM  05/20/2019 10:18:00 AM
# 13234    A721033  Lil Bit  04/05/2018 05:59:00 PM  04/05/2018 05:59:00 PM
# 20122    A721033  Lil Bit  09/24/2018 07:44:00 PM  09/24/2018 07:44:00 PM
# 24090    A721033  Lil Bit  03/15/2017 09:24:00 AM  03/15/2017 09:24:00 AM
# 25878    A721033  Lil Bit  02/12/2019 10:21:00 AM  02/12/2019 10:21:00 AM
# 27498    A721033  Lil Bit  09/21/2018 03:01:00 PM  09/21/2018 03:01:00 PM
# 27808    A721033  Lil Bit  10/05/2019 12:31:00 PM  10/05/2019 12:31:00 PM
# 29038    A721033  Lil Bit  10/20/2016 10:47:00 PM  10/20/2016 10:47:00 PM
# 36356    A721033  Lil Bit  07/10/2016 11:53:00 AM  07/10/2016 11:53:00 AM
# 36606    A721033  Lil Bit  08/05/2019 10:52:00 AM  08/05/2019 10:52:00 AM
# ...
