# %%
# Imports
import pandas as pd

# %%
# Import intake CSV data
intake_df = pd.read_csv("Resources/Austin_Animal_Center_Intakes.csv")
intake_df.head()
# Out:
#   Animal ID     Name                DateTime               MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  01/03/2019 04:19:00 PM
# 1   A706918    Belle  07/05/2015 12:59:00 PM  07/05/2015 12:59:00 PM
# 2   A724273  Runster  04/14/2016 06:43:00 PM  04/14/2016 06:43:00 PM
# 3   A665644      NaN  10/21/2013 07:59:00 AM  10/21/2013 07:59:00 AM
# 4   A682524      Rio  06/29/2014 10:38:00 AM  06/29/2014 10:38:00 AM
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color
# 0                             Beagle Mix     Tricolor
# 1               English Springer Spaniel  White/Liver
# 2                            Basenji Mix  Sable/White
# 3                 Domestic Shorthair Mix       Calico
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray

# %%
data = [intake_df["Animal ID"], intake_df["Age upon Intake"]]
headers = ["ID", "Age"]
intake_age_df = pd.concat(data, axis=1, keys=headers)
intake_age_df.head()
# Out:
#         ID        Age
# 0  A786884    2 years
# 1  A706918    8 years
# 2  A724273  11 months
# 3  A665644    4 weeks
# 4  A682524    4 years

# %%
# new data frame with split value columns
new = intake_age_df["Age"].str.split(" ", n = 1, expand = True)

# making separate columns for the number and string from new data frame
intake_age_df["Age_Value"]= new[0]
intake_age_df["Age_Unit"]= new[1]

intake_age_df
# Out:
#              ID        Age Age_Value Age_Unit
# 0       A786884    2 years         2    years
# 1       A706918    8 years         8    years
# 2       A724273  11 months        11   months
# 3       A665644    4 weeks         4    weeks
# 4       A682524    4 years         4    years
# ...         ...        ...       ...      ...
# 135657  A844937   3 months         3   months
# 135658  A849878   7 months         7   months
# 135659  A844379    2 years         2    years
# 135660  A848718    4 years         4    years
# 135661  A850105  10 months        10   months
#
# [135662 rows x 4 columns]

# %%
unit_counts = intake_age_df.Age_Unit.value_counts()
unit_counts
# Out:
# years     53666
# months    28399
# year      23247
# month     13341
# weeks     13057
# days       2126
# week       1110
# day         716
# Name: Age_Unit, dtype: int64

# %%
# convert ages in months to ages in years

for row in intake_age_df.index:
    if((intake_age_df["Age_Unit"].values[row] == "months") | (intake_age_df["Age_Unit"].values[row] == "month")):
        intake_age_df["Age_Value"].values[row] = float(intake_age_df["Age_Value"].values[row])/12
    if((intake_age_df["Age_Unit"].values[row] == "weeks") | (intake_age_df["Age_Unit"].values[row] == "week")):
        intake_age_df["Age_Value"].values[row] = float(intake_age_df["Age_Value"].values[row])/52
    if((intake_age_df["Age_Unit"].values[row] == "days") | (intake_age_df["Age_Unit"].values[row] == "day")):
        intake_age_df["Age_Value"].values[row] = float(intake_age_df["Age_Value"].values[row])/365
    if((intake_age_df["Age_Unit"].values[row] == "years") | (intake_age_df["Age_Unit"].values[row] == "year")):
        intake_age_df["Age_Value"].values[row] = float(intake_age_df["Age_Value"].values[row])
        
intake_age_df
# Out:
#              ID        Age Age_Value Age_Unit
# 0       A786884    2 years       2.0    years
# 1       A706918    8 years       8.0    years
# 2       A724273  11 months  0.916667   months
# 3       A665644    4 weeks  0.076923    weeks
# 4       A682524    4 years       4.0    years
# ...         ...        ...       ...      ...
# 135657  A844937   3 months      0.25   months
# 135658  A849878   7 months  0.583333   months
# 135659  A844379    2 years       2.0    years
# 135660  A848718    4 years       4.0    years
# 135661  A850105  10 months  0.833333   months
#
# [135662 rows x 4 columns]

# %%
# put converted age back into intake dataframe
intake_df["Age_in_Years"] = intake_age_df["Age_Value"]
intake_df.head()
# Out:
#   Animal ID     Name                DateTime               MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  01/03/2019 04:19:00 PM
# 1   A706918    Belle  07/05/2015 12:59:00 PM  07/05/2015 12:59:00 PM
# 2   A724273  Runster  04/14/2016 06:43:00 PM  04/14/2016 06:43:00 PM
# 3   A665644      NaN  10/21/2013 07:59:00 AM  10/21/2013 07:59:00 AM
# 4   A682524      Rio  06/29/2014 10:38:00 AM  06/29/2014 10:38:00 AM
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color Age_in_Years
# 0                             Beagle Mix     Tricolor          2.0
# 1               English Springer Spaniel  White/Liver          8.0
# 2                            Basenji Mix  Sable/White     0.916667
# 3                 Domestic Shorthair Mix       Calico     0.076923
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray          4.0

# %%
intake_df=intake_df[intake_df["Animal Type"]=="Dog"]

# %%
intake_working = intake_df.loc[:, ["Animal ID","DateTime","Sex upon Intake","Breed","Age_in_Years"]]
intake_working.head()
# Out:
#   Animal ID                DateTime Sex upon Intake  \
# 0   A786884  01/03/2019 04:19:00 PM   Neutered Male
# 1   A706918  07/05/2015 12:59:00 PM   Spayed Female
# 2   A724273  04/14/2016 06:43:00 PM     Intact Male
# 4   A682524  06/29/2014 10:38:00 AM   Neutered Male
# 5   A743852  02/18/2017 12:46:00 PM   Neutered Male
#
#                                    Breed Age_in_Years
# 0                             Beagle Mix          2.0
# 1               English Springer Spaniel          8.0
# 2                            Basenji Mix     0.916667
# 4  Doberman Pinsch/Australian Cattle Dog          4.0
# 5                 Labrador Retriever Mix          2.0

# %%
sexsplit=intake_working["Sex upon Intake"].str.split(" ",n=1, expand=True)
sexsplit
# Out:
#                0       1
# 0       Neutered    Male
# 1         Spayed  Female
# 2         Intact    Male
# 4       Neutered    Male
# 5       Neutered    Male
# ...          ...     ...
# 135655    Intact    Male
# 135656  Neutered    Male
# 135658    Intact  Female
# 135660    Intact  Female
# 135661    Intact    Male
#
# [76334 rows x 2 columns]

# %%
intake_working["Sex"]=sexsplit[1]

# %%
intake_working["SpayNeuter"]=sexsplit[0]

# %%
intake_working.drop(columns="Sex upon Intake", inplace=True)
intake_working.head()
# Out:
#   Animal ID                DateTime                                  Breed  \
# 0   A786884  01/03/2019 04:19:00 PM                             Beagle Mix
# 1   A706918  07/05/2015 12:59:00 PM               English Springer Spaniel
# 2   A724273  04/14/2016 06:43:00 PM                            Basenji Mix
# 4   A682524  06/29/2014 10:38:00 AM  Doberman Pinsch/Australian Cattle Dog
# 5   A743852  02/18/2017 12:46:00 PM                 Labrador Retriever Mix
#
#   Age_in_Years     Sex SpayNeuter
# 0          2.0    Male   Neutered
# 1          8.0  Female     Spayed
# 2     0.916667    Male     Intact
# 4          4.0    Male   Neutered
# 5          2.0    Male   Neutered

# %%
intake_working["str_mix"]=intake_working["Breed"].str.find("Mix")
intake_working.loc[intake_working["str_mix"]>=0, ["str_mix"]]=1
intake_working.loc[intake_working["str_mix"]==-1,["str_mix"]]=0

intake_working["str_slash"]=intake_working["Breed"].str.find("/")
intake_working.loc[intake_working["str_slash"]>=0, ["str_slash"]]=1
intake_working.loc[intake_working["str_slash"]==-1,["str_slash"]]=0

intake_working["Mix"]=0
intake_working.loc[intake_working["str_mix"]==1, ["Mix"]]=1
intake_working.loc[intake_working["str_slash"]==1, ["Mix"]]=1
    

intake_working.head()
# Out:
#   Animal ID                DateTime                                  Breed  \
# 0   A786884  01/03/2019 04:19:00 PM                             Beagle Mix
# 1   A706918  07/05/2015 12:59:00 PM               English Springer Spaniel
# 2   A724273  04/14/2016 06:43:00 PM                            Basenji Mix
# 4   A682524  06/29/2014 10:38:00 AM  Doberman Pinsch/Australian Cattle Dog
# 5   A743852  02/18/2017 12:46:00 PM                 Labrador Retriever Mix
#
#   Age_in_Years     Sex SpayNeuter  str_mix  str_slash  Mix
# 0          2.0    Male   Neutered        1          0    1
# 1          8.0  Female     Spayed        0          0    0
# 2     0.916667    Male     Intact        1          0    1
# 4          4.0    Male   Neutered        0          1    1
# 5          2.0    Male   Neutered        1          0    1

# %%
# Make sure there are no other markers for mix.
intake_working["Breed"].str.find("mix").value_counts()
# Out:
# -1    76334
# Name: Breed, dtype: int64

# %%
ands=intake_working[intake_working["Breed"].str.find("\sand")>-1]
ands
# Out:
# Empty DataFrame
# Columns: [Animal ID, DateTime, Breed, Age_in_Years, Sex, SpayNeuter, str_mix, str_slash, Mix]
# Index: []

# %%
from collections import Counter 
Counter(intake_working["Breed"])

# **Note, breed match may not work for Anatol Shepherd, Pbgv and Bruss Griffon,  bc first abbrev.
# No sign of any other marker for mix than "and" and "/"
# Out:
# Counter({'Beagle Mix': 619,
#          'English Springer Spaniel': 8,
#          'Basenji Mix': 80,
#          'Doberman Pinsch/Australian Cattle Dog': 2,
#          'Labrador Retriever Mix': 7312,
#          'Great Dane Mix': 121,
#          'Chihuahua Shorthair': 1301,
#          'Pit Bull': 1837,
#          'Australian Cattle Dog/Labrador Retriever': 102,
#          'Parson Russell Terrier Mix': 50,
#          'Norfolk Terrier': 15,
#          'Yorkshire Terrier Mix': 642,
#          'Maltese Mix': 230,
#          'Rottweiler Mix': 456,
#          'Dachshund Mix': 1084,
#          'Boxer Mix': 1035,
#          'Plott Hound Mix': 425,
#          'Labrador Retriever': 1282,
#          'Pit Bull Mix': 8853,
#          'Tibetan Spaniel Mix': 36,
#          'Miniature Pinscher Mix': 214,
#          'Chihuahua Shorthair Mix': 6459,
#          'Pit Bull/Australian Cattle Dog': 54,
#          'Yorkshire Terrier': 140,
#          'Dachshund/Chihuahua Shorthair': 294,
#          'German Shepherd/Chow Chow': 31,
#          'Miniature Schnauzer Mix': 614,
#          'German Shepherd/Australian Cattle Dog': 44,
#          'German Shepherd': 1136,
#          'Great Dane': 69,
#          'Australian Kelpie Mix': 397,
#          'Alaskan Husky': 89,
#          'Great Pyrenees Mix': 611,
#          'German Shepherd Mix': 3273,
#          'Feist/Beagle': 3,
#          'American Pit Bull Terrier Mix': 344,
#          'Norfolk Terrier Mix': 108,
#          'Chihuahua Shorthair/Jack Russell Terrier': 69,
#          'Italian Greyhound Mix': 36,
#          'Treeing Walker Coonhound Mix': 55,
#          'Boxer': 240,
#          'Staffordshire/English Bulldog': 8,
#          'Bull Terrier Mix': 110,
#          'Australian Shepherd/Chow Chow': 9,
#          'Chihuahua Longhair Mix': 510,
#          'Black Mouth Cur/Pit Bull': 15,
#          'Boston Terrier/Pembroke Welsh Corgi': 2,
#          'Black Mouth Cur Mix': 417,
#          'German Shepherd/Great Pyrenees': 27,
#          'Cairn Terrier Mix': 535,
#          'Miniature Schnauzer/Miniature Poodle': 93,
#          'Pointer/Beagle': 12,
#          'American Staffordshire Terrier Mix': 282,
#          'Collie Smooth Mix': 113,
#          'Standard Schnauzer': 14,
#          'Papillon Mix': 61,
#          'Labrador Retriever/Beagle': 75,
#          'Staffordshire': 91,
#          'Labrador Retriever/Border Collie': 153,
#          'Siberian Husky Mix': 750,
#          'Bloodhound': 15,
#          'Jack Russell Terrier Mix': 575,
#          'Toy Fox Terrier Mix': 30,
#          'Labrador Retriever/Rhod Ridgeback': 11,
#          'Plott Hound': 55,
#          'Beagle/Dachshund': 49,
#          'Siberian Husky': 521,
#          'Shih Tzu': 224,
#          'Australian Cattle Dog': 357,
#          'Rottweiler/German Shepherd': 23,
#          'Australian Shepherd Mix': 737,
#          'Basenji/Australian Cattle Dog': 4,
#          'Pit Bull/Boxer': 106,
#          'Lhasa Apso Mix': 154,
#          'Pomeranian': 60,
#          'Shih Tzu/Chihuahua Shorthair': 14,
#          'Miniature Schnauzer/Yorkshire Terrier': 22,
#          'American Bulldog Mix': 485,
#          'Shih Tzu Mix': 413,
#          'Labrador Retriever/Great Pyrenees': 119,
#          'Miniature Schnauzer': 126,
#          'Rat Terrier': 101,
#          'Rat Terrier Mix': 654,
#          'Norfolk Terrier/Chihuahua Shorthair': 22,
#          'Labrador Retriever/Pointer': 60,
#          'Smooth Fox Terrier': 12,
#          'Border Collie Mix': 1000,
#          'Miniature Pinscher/Yorkshire Terrier': 1,
#          'Australian Cattle Dog Mix': 1626,
#          'Rhod Ridgeback/Labrador Retriever': 20,
#          'Queensland Heeler Mix': 177,
#          'Golden Retriever Mix': 246,
#          'Mastiff/Rottweiler': 5,
#          'Dachshund Wirehair/Border Terrier': 8,
#          'Irish Wolfhound Mix': 14,
#          'Welsh Terrier': 26,
#          'German Shepherd/Cardigan Welsh Corgi': 12,
#          'Labrador Retriever/German Shepherd': 283,
#          'Bruss Griffon Mix': 54,
#          'Wire Hair Fox Terrier Mix': 59,
#          'Australian Cattle Dog/Rhod Ridgeback': 2,
#          'Blue Lacy Mix': 192,
#          'Chihuahua Longhair/Dachshund Wirehair': 2,
#          'Chihuahua Shorthair/Dachshund': 384,
#          'Alaskan Husky/German Shepherd': 42,
#          'Cairn Terrier': 152,
#          'Catahoula Mix': 736,
#          'Boston Terrier': 71,
#          'Dachshund/Cardigan Welsh Corgi': 7,
#          'Cardigan Welsh Corgi Mix': 152,
#          'Alaskan Husky Mix': 138,
#          'Smooth Fox Terrier Mix': 51,
#          'Labrador Retriever/Pit Bull': 393,
#          'Shetland Sheepdog Mix': 55,
#          'Labrador Retriever/Anatol Shepherd': 30,
#          'Pit Bull/Labrador Retriever': 246,
#          'Catahoula/Australian Cattle Dog': 17,
#          'German Shepherd/Labrador Retriever': 325,
#          'Presa Canario Mix': 9,
#          'Chesa Bay Retr Mix': 25,
#          'German Shorthair Pointer Mix': 63,
#          'Pointer Mix': 551,
#          'American Pit Bull Terrier': 155,
#          'Silky Terrier Mix': 14,
#          'Labrador Retriever/Australian Cattle Dog': 129,
#          'Beagle': 150,
#          'Australian Cattle Dog/Beagle': 17,
#          'Pointer/Rat Terrier': 4,
#          'Toy Poodle Mix': 122,
#          'Tibetan Spaniel/Chihuahua Longhair': 2,
#          'Dachshund': 236,
#          'Miniature Poodle Mix': 871,
#          'Australian Cattle Dog/Chinese Sharpei': 4,
#          'Great Pyrenees/German Shepherd': 14,
#          'Rottweiler/Siberian Husky': 5,
#          'Great Pyrenees': 276,
#          'Toy Poodle': 45,
#          'Border Terrier/Chihuahua Shorthair': 14,
#          'Rat Terrier/Chihuahua Shorthair': 84,
#          'Labrador Retriever/Australian Shepherd': 45,
#          'Pug Mix': 160,
#          'Harrier Mix': 91,
#          'Standard Poodle Mix': 31,
#          'Airedale Terrier Mix': 28,
#          'Chow Chow/Australian Kelpie': 1,
#          'Dachshund/Beagle': 37,
#          'Jack Russell Terrier/Chihuahua Shorthair': 69,
#          'Akita Mix': 61,
#          'Black/Tan Hound Mix': 131,
#          'Chihuahua Shorthair/Rat Terrier': 90,
#          'Border Collie/Labrador Retriever': 123,
#          'Staffordshire Mix': 716,
#          'Carolina Dog': 20,
#          'Redbone Hound Mix': 95,
#          'Bloodhound Mix': 38,
#          'Chihuahua Shorthair/French Bulldog': 2,
#          'Anatol Shepherd': 95,
#          'Bullmastiff Mix': 34,
#          'Pit Bull/Plott Hound': 10,
#          'Norwich Terrier/Yorkshire Terrier': 6,
#          'Australian Shepherd': 114,
#          'Bichon Frise/Pekingese': 1,
#          'Labrador Retriever/Boxer': 88,
#          'Vizsla Mix': 55,
#          'Greater Swiss Mountain Dog': 1,
#          'Dachshund/Bloodhound': 3,
#          'Cairn Terrier/Chihuahua Shorthair': 35,
#          'Schnauzer Giant Mix': 28,
#          'Miniature Poodle/Australian Shepherd': 1,
#          'Anatol Shepherd Mix': 453,
#          'Whippet Mix': 86,
#          'Anatol Shepherd/Alaskan Husky': 4,
#          'Chesa Bay Retr/Pit Bull': 1,
#          'Flat Coat Retriever/Pit Bull': 3,
#          'English Bulldog Mix': 97,
#          'English Shepherd Mix': 12,
#          'Dogo Argentino Mix': 28,
#          'Catahoula/Harrier': 3,
#          'Dachshund/Dachshund': 2,
#          'Beagle/Rat Terrier': 9,
#          'Basset Hound/Labrador Retriever': 19,
#          'Catahoula': 93,
#          'Beagle/Cardigan Welsh Corgi': 3,
#          'Old English Sheepdog': 3,
#          'Boxer/American Bulldog': 5,
#          'Border Terrier Mix': 213,
#          'Pomeranian Mix': 159,
#          'Chinese Sharpei': 36,
#          'German Shepherd/Siberian Husky': 79,
#          'Chihuahua Shorthair/American Staffordshire Terrier': 3,
#          'Manchester Terrier Mix': 121,
#          'Rhod Ridgeback Mix': 104,
#          'Basset Hound Mix': 166,
#          'Labrador Retriever/Chinese Sharpei': 46,
#          'German Shepherd/Weimaraner': 1,
#          'Basset Hound': 63,
#          'American Pit Bull Terrier/Dachshund': 2,
#          'Chinese Sharpei Mix': 147,
#          'Pit Bull/Catahoula': 39,
#          'Miniature Poodle/Maltese': 41,
#          'Black Mouth Cur': 51,
#          'Dogue De Bordeaux Mix': 19,
#          'Australian Shepherd/Anatol Shepherd': 7,
#          'Chihuahua Shorthair/Catahoula': 4,
#          'Scottish Terrier Mix': 37,
#          'Belgian Malinois': 49,
#          'Doberman Pinsch/German Shepherd': 6,
#          'Vizsla/Boxer': 2,
#          'Irish Terrier': 6,
#          'Doberman Pinsch Mix': 184,
#          'Plott Hound/Australian Cattle Dog': 7,
#          'Border Terrier/Scottish Terrier': 3,
#          'Australian Terrier Mix': 23,
#          'Greyhound': 15,
#          'American Eskimo': 14,
#          'Border Collie/Great Pyrenees': 31,
#          'Irish Terrier/Basset Hound': 4,
#          'Miniature Poodle': 169,
#          'Labrador Retriever/Dachshund': 31,
#          'Doberman Pinsch': 134,
#          'Nova Scotia Duck Tolling Retriever Mix': 7,
#          'American Staffordshire Terrier/Plott Hound': 1,
#          'Pembroke Welsh Corgi Mix': 86,
#          'West Highland/Cairn Terrier': 2,
#          'Labrador Retriever/Shiba Inu': 3,
#          'Dachshund Wirehair Mix': 114,
#          'Cocker Spaniel/Miniature Poodle': 20,
#          'Plott Hound/Boxer': 5,
#          'Soft Coated Wheaten Terrier Mix': 76,
#          'Beagle/German Shepherd': 25,
#          'Dutch Shepherd Mix': 60,
#          'Great Dane/Mastiff': 3,
#          'Chihuahua Shorthair/Smooth Fox Terrier': 4,
#          'Rottweiler': 225,
#          'Havanese Mix': 38,
#          'Pekingese': 43,
#          'Queensland Heeler/Dachshund': 2,
#          'Collie Rough': 10,
#          'Pointer': 87,
#          'Pug/Chihuahua Shorthair': 50,
#          'Pit Bull/Chinese Sharpei': 39,
#          'Black/Tan Hound': 25,
#          'Catahoula/Plott Hound': 21,
#          'Soft Coated Wheaten Terrier': 22,
#          'Shiba Inu Mix': 52,
#          'Boxer/Pit Bull': 94,
#          'Miniature Pinscher': 86,
#          'Cocker Spaniel Mix': 149,
#          'Chihuahua Shorthair/Parson Russell Terrier': 5,
#          'Chow Chow Mix': 185,
#          'Miniature Poodle/Scottish Terrier': 1,
#          'Dachshund Longhair Mix': 128,
#          'Chinese Sharpei/Labrador Retriever': 28,
#          'Chihuahua Shorthair/Cardigan Welsh Corgi': 39,
#          'Chihuahua Shorthair/Yorkshire Terrier': 31,
#          'Smooth Fox Terrier/Jack Russell Terrier': 2,
#          'Australian Cattle Dog/German Shepherd': 55,
#          'Maltese/Miniature Poodle': 100,
#          'West Highland Mix': 69,
#          'Labrador Retriever/Catahoula': 43,
#          'Bruss Griffon/Pug': 4,
#          'Bichon Frise Mix': 72,
#          'Labrador Retriever/Australian Kelpie': 20,
#          'Miniature Schnauzer/Dachshund Wirehair': 4,
#          'Norfolk Terrier/Yorkshire Terrier': 5,
#          'Cocker Spaniel': 81,
#          'Border Collie/Pointer': 6,
#          'Chihuahua Shorthair/Cairn Terrier': 28,
#          'German Shepherd/Mastiff': 8,
#          'Labrador Retriever/Siberian Husky': 35,
#          'Dalmatian': 13,
#          'Australian Kelpie': 36,
#          'Standard Poodle/Labrador Retriever': 19,
#          'Akita/German Shepherd': 7,
#          'Labrador Retriever/Blue Lacy': 18,
#          'Bichon Frise/Miniature Poodle': 4,
#          'St. Bernard Smooth Coat Mix': 22,
#          'Staffordshire/American Bulldog': 1,
#          'Chihuahua Shorthair/Pug': 85,
#          'English Bulldog': 73,
#          'American Bulldog/Pit Bull': 25,
#          'Chihuahua Shorthair/Boston Terrier': 21,
#          'Jack Russell Terrier': 93,
#          'Tibetan Mastiff Mix': 1,
#          'Bull Terrier': 57,
#          'Pekingese Mix': 94,
#          'Coton De Tulear Mix': 4,
#          'French Bulldog Mix': 21,
#          'Border Collie': 147,
#          'Lhasa Apso/Miniature Poodle': 22,
#          'Blue Lacy/Weimaraner': 2,
#          'Anatol Shepherd/Redbone Hound': 4,
#          'American Eskimo Mix': 34,
#          'Great Pyrenees/Standard Poodle': 4,
#          'English Pointer Mix': 33,
#          'English Bulldog/American Staffordshire Terrier': 1,
#          'Cane Corso': 18,
#          'Golden Retriever/Chow Chow': 15,
#          'Black Mouth Cur/Golden Retriever': 1,
#          'Bullmastiff': 14,
#          'Golden Retriever/Finnish Spitz': 1,
#          'Pharaoh Hound Mix': 44,
#          'Hovawart/Flat Coat Retriever': 2,
#          'Belgian Malinois/German Shepherd': 12,
#          'Labrador Retriever/Basset Hound': 24,
#          'Queensland Heeler': 37,
#          'Brittany Mix': 30,
#          'Great Dane/Pit Bull': 5,
#          'Brittany': 11,
#          'Black/Tan Hound/German Shepherd': 2,
#          'Rottweiler/Labrador Retriever': 46,
#          'Dalmatian/Basset Hound': 1,
#          'Labrador Retriever/Chow Chow': 55,
#          'Labrador Retriever/Jack Russell Terrier': 11,
#          'Shiba Inu': 11,
#          'Labrador Retriever/Flat Coat Retriever': 8,
#          'Newfoundland/Australian Cattle Dog': 1,
#          'Australian Cattle Dog/Boxer': 16,
#          'Australian Cattle Dog/Plott Hound': 5,
#          'French Bulldog': 29,
#          'Alaskan Malamute/German Shepherd': 9,
#          'Cairn Terrier/Yorkshire Terrier': 13,
#          'Pug/Beagle': 54,
#          'Plott Hound/Carolina Dog': 1,
#          'Pit Bull/German Shepherd': 28,
#          'Boxer/Labrador Retriever': 87,
#          'Carolina Dog Mix': 97,
#          'Maltese': 101,
#          'Weimaraner/Labrador Retriever': 18,
#          'Silky Terrier/Yorkshire Terrier': 4,
#          'Australian Shepherd/Cardigan Welsh Corgi': 5,
#          'Dachshund Longhair/Chihuahua Longhair': 17,
#          'Boerboel Mix': 7,
#          'Chinese Sharpei/Chow Chow': 1,
#          'Anatol Shepherd/Mastiff': 3,
#          'Chow Chow/Pit Bull': 7,
#          'Dachshund/Manchester Terrier': 12,
#          'Black Mouth Cur/Beagle': 2,
#          'Mastiff': 35,
#          'American Bulldog': 89,
#          'Catahoula/Boxer': 5,
#          'Anatol Shepherd/Australian Cattle Dog': 2,
#          'Pit Bull/Basset Hound': 13,
#          'Pug': 114,
#          'Shetland Sheepdog/Border Collie': 5,
#          'Vizsla': 25,
#          'Rottweiler/Beagle': 4,
#          'Landseer/Border Collie': 1,
#          'Saluki': 5,
#          'Chihuahua Longhair': 104,
#          'Cocker Spaniel/Dachshund': 8,
#          'Standard Poodle': 17,
#          'St. Bernard Rough Coat/Beagle': 1,
#          'Mastiff Mix': 147,
#          'Field Spaniel Mix': 13,
#          'Australian Shepherd/Golden Retriever': 2,
#          'German Shepherd/Golden Retriever': 8,
#          'Shih Tzu/Dachshund Longhair': 1,
#          'Whippet/Australian Kelpie': 3,
#          'Port Water Dog Mix': 2,
#          'Staffordshire/Pit Bull': 2,
#          'Alaskan Malamute': 21,
#          'Boston Terrier Mix': 134,
#          'Australian Cattle Dog/Akita': 8,
#          'Boxer/Beagle': 18,
#          'Labrador Retriever/Rottweiler': 44,
#          'Pointer/Labrador Retriever': 61,
#          'German Shorthair Pointer/Australian Cattle Dog': 13,
#          'Chow Chow/Chinese Sharpei': 2,
#          'Bulldog Mix': 54,
#          'St. Bernard Smooth Coat': 6,
#          'Australian Shepherd/German Shepherd': 15,
#          'Australian Shepherd/Australian Kelpie': 1,
#          'Redbone Hound': 17,
#          'Dachshund/Rat Terrier': 21,
#          'Golden Retriever/Irish Setter': 1,
#          'St. Bernard Rough Coat': 7,
#          'Border Terrier': 48,
#          'Shiba Inu/Australian Kelpie': 4,
#          'American Pit Bull Terrier/Labrador Retriever': 6,
#          'Cardigan Welsh Corgi/Miniature Schnauzer': 1,
#          'Cardigan Welsh Corgi/Cocker Spaniel': 3,
#          'Boston Terrier/Beagle': 2,
#          'Dachshund Wirehair/Norfolk Terrier': 2,
#          'Great Pyrenees/Labrador Retriever': 77,
#          'Beagle/Pembroke Welsh Corgi': 1,
#          'Yorkshire Terrier/Miniature Poodle': 33,
#          'Maltese/Jack Russell Terrier': 2,
#          'Toy Fox Terrier': 9,
#          'Jack Russell Terrier/Shih Tzu': 4,
#          'Chihuahua Shorthair/Chinese Crested': 2,
#          'English Shepherd': 4,
#          'Jack Russell Terrier/Italian Greyhound': 2,
#          'Pit Bull/Dachshund': 6,
#          'Anatol Shepherd/Labrador Retriever': 33,
#          'Shih Tzu/Yorkshire Terrier': 7,
#          'German Shepherd/Black Mouth Cur': 17,
#          'Border Terrier/Dachshund': 9,
#          'Boxer/Catahoula': 7,
#          'Blue Lacy': 35,
#          'Labrador Retriever/Collie Rough': 4,
#          'Pit Bull/Chow Chow': 7,
#          'Chinese Crested': 3,
#          'Belgian Malinois Mix': 95,
#          'German Shepherd/Border Collie': 19,
#          'Wirehaired Pointing Griffon Mix': 10,
#          'Bichon Frise': 25,
#          'Flat Coat Retriever Mix': 119,
#          'Catahoula/Pit Bull': 24,
#          'Wire Hair Fox Terrier': 51,
#          'Glen Of Imaal Mix': 13,
#          'Jack Russell Terrier/Labrador Retriever': 11,
#          'Kangal Mix': 2,
#          'Black Mouth Cur/Doberman Pinsch': 7,
#          'Welsh Terrier Mix': 15,
#          'Standard Schnauzer Mix': 64,
#          'Treeing Walker Coonhound/German Shepherd': 3,
#          'Border Collie/Greyhound': 4,
#          'West Highland': 21,
#          'Shih Tzu/Cardigan Welsh Corgi': 2,
#          'Siberian Husky/German Shepherd': 76,
#          'German Shepherd/Alaskan Husky': 38,
#          'Anatol Shepherd/Great Pyrenees': 34,
#          'Jack Russell Terrier/Border Collie': 4,
#          'Weimaraner Mix': 60,
#          'Pointer/Pit Bull': 43,
#          'Patterdale Terr Mix': 14,
#          'Dalmatian Mix': 61,
#          'Great Pyrenees/Siberian Husky': 1,
#          'German Shepherd/Catahoula': 17,
#          'Beauceron Mix': 31,
#          'Basset Hound/Pit Bull': 12,
#          'Chihuahua Longhair/Silky Terrier': 1,
#          'Labrador Retriever/Akita': 1,
#          'English Coonhound Mix': 40,
#          'Chihuahua Shorthair/Dachshund Wirehair': 11,
#          'Cairn Terrier/Dachshund Wirehair': 4,
#          'Norwich Terrier': 11,
#          'Anatol Shepherd/Kangal': 2,
#          'Cane Corso Mix': 19,
#          'American Pit Bull Terrier/Boxer': 2,
#          'Cairn Terrier/Border Collie': 2,
#          'Pit Bull/Boston Terrier': 9,
#          'Black/Tan Hound/Labrador Retriever': 14,
#          'Norwich Terrier/Pug': 1,
#          'Beagle/Pug': 31,
#          'Beagle/Basset Hound': 15,
#          'Dachshund Longhair/Tibetan Spaniel': 1,
#          'Miniature Pinscher/Chihuahua Shorthair': 31,
#          'Pembroke Welsh Corgi': 21,
#          'Boxer/Staffordshire': 10,
#          'Alaskan Husky/Australian Shepherd': 4,
#          'English Foxhound Mix': 13,
#          'St. Bernard Rough Coat Mix': 29,
#          'Australian Shepherd/Border Collie': 27,
#          'Rhod Ridgeback/Redbone Hound': 1,
#          'Great Pyrenees/Chow Chow': 5,
#          'Golden Retriever/Labrador Retriever': 41,
#          'Australian Terrier': 3,
#          'Papillon/Pomeranian': 1,
#          'Shih Tzu/Miniature Schnauzer': 5,
#          'Collie Rough/Australian Shepherd': 2,
#          'German Shepherd/Chinese Sharpei': 10,
#          'Spinone Italiano Mix': 3,
#          'Harrier': 15,
#          'Dachshund Wirehair': 11,
#          'American Bulldog/Boxer': 10,
#          'Beagle/Australian Cattle Dog': 13,
#          'Collie Rough Mix': 53,
#          'Yorkshire Terrier/Norfolk Terrier': 8,
#          'Border Collie/Beagle': 7,
#          'Chihuahua Longhair/Dachshund Longhair': 4,
#          'Labrador Retriever/Alaskan Husky': 13,
#          'Norwich Terrier/Maltese': 3,
#          'Dachshund Longhair': 44,
#          'Bluetick Hound Mix': 27,
#          'Pit Bull/Black Mouth Cur': 10,
#          'Otterhound Mix': 7,
#          'Labrador Retriever/Greyhound': 16,
#          'Pbgv Mix': 60,
#          'Siberian Husky/Australian Cattle Dog': 18,
#          'Border Collie/German Shepherd': 40,
#          'Staffordshire/Bull Terrier': 3,
#          'German Shepherd/Rottweiler': 27,
#          'Siberian Husky/Border Collie': 11,
#          'Great Pyrenees/Border Collie': 21,
#          'Pointer/Chinese Sharpei': 1,
#          'Vizsla/German Shepherd': 2,
#          'Pit Bull/Blue Lacy': 8,
#          'Labrador Retriever/Black/Tan Hound': 14,
#          'Basset Hound/Beagle': 10,
#          'German Shepherd/Pointer': 4,
#          'Scottish Terrier/Basset Hound': 1,
#          'Anatol Shepherd/Chow Chow': 4,
#          'Basset Hound/Australian Cattle Dog': 7,
#          'Australian Cattle Dog/Bull Terrier': 5,
#          'Miniature Schnauzer/Labrador Retriever': 4,
#          'Cocker Spaniel/Labrador Retriever': 15,
#          'Siberian Husky/French Bulldog': 1,
#          'Akita/Labrador Retriever': 4,
#          'Cocker Spaniel/Chihuahua Shorthair': 3,
#          'American Staffordshire Terrier': 87,
#          'German Shepherd/Australian Kelpie': 16,
#          'English Bulldog/Boxer': 2,
#          'Rottweiler/Dachshund': 1,
#          'Pit Bull/Chihuahua Shorthair': 15,
#          'Norfolk Terrier/Dachshund Wirehair': 1,
#          'Cardigan Welsh Corgi': 20,
#          'Catahoula/Pointer': 8,
#          'Cavalier Span Mix': 30,
#          'Landseer': 5,
#          'Staffordshire/Labrador Retriever': 12,
#          'Jindo Mix': 14,
#          'Alaskan Malamute/Australian Kelpie': 1,
#          'Schipperke Mix': 17,
#          'American Pit Bull Terrier/Pit Bull': 2,
#          'Airedale Terrier/Otterhound': 2,
#          'Beagle/Chihuahua Shorthair': 39,
#          'Miniature Schnauzer/Beagle': 5,
#          'Jack Russell Terrier/Yorkshire Terrier': 5,
#          'Labrador Retriever/St. Bernard Smooth Coat': 1,
#          'Lhasa Apso/Shih Tzu': 6,
#          'Jack Russell Terrier/Rat Terrier': 10,
#          'Bull Terrier Miniature': 5,
#          'Australian Cattle Dog/Border Collie': 26,
#          'Chow Chow/Cardigan Welsh Corgi': 1,
#          'Pit Bull/Beagle': 6,
#          'German Shepherd/Boxer': 22,
#          'Shih Tzu/Miniature Poodle': 21,
#          'Pointer/Border Collie': 11,
#          'Norfolk Terrier/Cairn Terrier': 1,
#          'Great Pyrenees/American Bulldog': 8,
#          'Chihuahua Shorthair/Norfolk Terrier': 5,
#          'Chow Chow/Labrador Retriever': 20,
#          'Rat Terrier/Pointer': 2,
#          'Finnish Spitz Mix': 29,
#          'Dutch Shepherd/Belgian Malinois': 1,
#          'Treeing Tennesse Brindle Mix': 4,
#          'Cavalier Span': 16,
#          'Australian Shepherd/Plott Hound': 5,
#          'Collie Smooth/Boxer': 6,
#          'Chihuahua Shorthair/Norwich Terrier': 2,
#          'Mastiff/Pit Bull': 13,
#          'Pit Bull/Bullmastiff': 1,
#          'Gordon Setter Mix': 2,
#          'Labrador Retriever/Cardigan Welsh Corgi': 4,
#          'German Shepherd/Swedish Vallhund': 3,
#          'Chihuahua Shorthair/Miniature Pinscher': 26,
#          'Papillon': 13,
#          'Australian Shepherd/Labrador Retriever': 43,
#          'Great Pyrenees/Golden Retriever': 12,
#          'Dandie Dinmont Mix': 3,
#          'Black Mouth Cur/Dachshund': 2,
#          'Havanese': 9,
#          'German Shepherd/Pit Bull': 23,
#          'St. Bernard Rough Coat/Anatol Shepherd': 1,
#          'Chihuahua Shorthair/Pomeranian': 13,
#          'Great Pyrenees/Australian Shepherd': 6,
#          'Chihuahua Longhair/Rat Terrier': 7,
#          'Belgian Malinois/Australian Shepherd': 2,
#          'German Shorthair Pointer': 24,
#          'Pembroke Welsh Corgi/Golden Retriever': 1,
#          'Chow Chow': 39,
#          'Labrador Retriever/Bearded Collie': 9,
#          'Yorkshire Terrier/Border Terrier': 13,
#          'Dachshund/Labrador Retriever': 21,
#          'Boxer/Black Mouth Cur': 6,
#          'Plott Hound/Labrador Retriever': 37,
#          'Schipperke/Catahoula': 1,
#          'English Springer Spaniel Mix': 19,
#          'German Shepherd/Carolina Dog': 1,
#          'Pomeranian/American Eskimo': 1,
#          'Pit Bull/Dalmatian': 7,
#          'Border Collie/Pit Bull': 4,
#          'Boxer/Whippet': 2,
#          'Tibetan Terrier': 5,
#          'Miniature Poodle/Chihuahua Longhair': 2,
#          'Parson Russell Terrier': 17,
#          'Pug/Labrador Retriever': 7,
#          'Pug/Pekingese': 2,
#          'Border Collie/Australian Cattle Dog': 29,
#          'German Wirehaired Pointer Mix': 20,
#          'Chihuahua Shorthair/Beagle': 33,
#          'Jack Russell Terrier/Basenji': 4,
#          'Great Pyrenees/St. Bernard Smooth Coat': 7,
#          'Japanese Chin Mix': 8,
#          'Ibizan Hound': 2,
#          'Rat Terrier/Beagle': 10,
#          'Pharaoh Hound/Boxer': 3,
#          'Soft Coated Wheaten Terrier/Labrador Retriever': 3,
#          'Feist Mix': 19,
#          'Bull Terrier/Pit Bull': 3,
#          'Irish Wolfhound/American Pit Bull Terrier': 1,
#          'Belgian Sheepdog Mix': 5,
#          'Landseer Mix': 18,
#          'Chihuahua Shorthair/Whippet': 7,
#          'Basset Hound/Border Collie': 3,
#          'Miniature Poodle/Chihuahua Shorthair': 7,
#          'Boxer/Chinese Sharpei': 11,
#          'Chihuahua Shorthair/Australian Cattle Dog': 5,
#          'Greyhound/Weimaraner': 1,
#          'Collie Smooth/Labrador Retriever': 12,
#          'Labrador Retriever/Cocker Spaniel': 2,
#          'Australian Cattle Dog/Pointer': 12,
#          'Border Collie/Queensland Heeler': 2,
#          'Australian Cattle Dog/Belgian Malinois': 9,
#          'Bulldog': 12,
#          'Miniature Poodle/Miniature Schnauzer': 37,
#          'Labrador Retriever/Golden Retriever': 43,
#          'Chihuahua Shorthair/Pekingese': 3,
#          'Golden Retriever/Dachshund': 2,
#          'Siberian Husky/Pit Bull': 12,
#          'Cardigan Welsh Corgi/Chihuahua Shorthair': 24,
#          'Rottweiler/Chow Chow': 5,
#          'Labrador Retriever/Newfoundland': 3,
#          'Wire Hair Fox Terrier/Beagle': 4,
#          'Australian Shepherd/Standard Poodle': 1,
#          'Dutch Sheepdog': 1,
#          'Pit Bull/Pointer': 27,
#          'Australian Shepherd/English Setter': 1,
#          'Manchester Terrier/Chihuahua Shorthair': 13,
#          'Pekingese/Toy Poodle': 1,
#          'Rat Terrier/Labrador Retriever': 6,
#          'Blue Lacy/Pit Bull': 12,
#          'Australian Kelpie/American Pit Bull Terrier': 2,
#          'Chesa Bay Retr/German Shepherd': 1,
#          'American Staffordshire Terrier/Boxer': 4,
#          'Scottish Terrier/Chihuahua Shorthair': 1,
#          'German Shepherd/Akita': 4,
#          'Miniature Schnauzer/Lhasa Apso': 2,
#          'American Foxhound Mix': 28,
#          'Chihuahua Shorthair/Wire Hair Fox Terrier': 6,
#          'Australian Cattle Dog/Pit Bull': 49,
#          'Old English Sheepdog Mix': 8,
#          'German Shepherd/Bull Terrier': 2,
#          'Labrador Retriever/Miniature Poodle': 6,
#          'Tibetan Terrier Mix': 21,
#          'Miniature Schnauzer/Chihuahua Shorthair': 13,
#          'Australian Kelpie/Dachshund': 3,
#          'Beagle/Labrador Retriever': 57,
#          'Doberman Pinsch/Pit Bull': 4,
#          'Labrador Retriever/Redbone Hound': 9,
#          'Pit Bull/Alaskan Husky': 4,
#          'Soft Coated Wheaten Terrier/Miniature Poodle': 1,
#          'Norwich Terrier/Border Terrier': 1,
#          'Chihuahua Longhair/Pomeranian': 13,
#          'Unknown Mix': 3,
#          'German Shepherd/Irish Wolfhound': 3,
#          'Irish Wolfhound': 3,
#          'Whippet/Rat Terrier': 2,
#          'Dachshund/Chinese Sharpei': 1,
#          'American Foxhound/Labrador Retriever': 2,
#          'Miniature Poodle/Shih Tzu': 8,
#          'Labrador Retriever/Mastiff': 13,
#          'Alaskan Malamute Mix': 31,
#          'Catahoula/German Shepherd': 8,
#          'Labrador Retriever/Rat Terrier': 3,
#          'Jack Russell Terrier/Australian Cattle Dog': 16,
#          'Whippet/Australian Cattle Dog': 2,
#          'Labrador Retriever/English Springer Spaniel': 2,
#          'Great Pyrenees/Anatol Shepherd': 24,
#          'Jack Russell Terrier/Welsh Terrier': 2,
#          'Chinese Crested/Cocker Spaniel': 2,
#          'Chow Chow/Alaskan Husky': 2,
#          'Pointer/Australian Cattle Dog': 20,
#          'Chinese Sharpei/Rottweiler': 1,
#          'Cocker Spaniel/Pekingese': 1,
#          'Boxer/Anatol Shepherd': 4,
#          'Basset Hound/German Shepherd': 3,
#          'Dachshund Longhair/Cocker Spaniel': 5,
#          'Jindo/Pembroke Welsh Corgi': 2,
#          'Miniature Poodle/Cocker Spaniel': 19,
#          'Pit Bull/Weimaraner': 6,
#          'Jack Russell Terrier/Pembroke Welsh Corgi': 4,
#          'Catahoula/Rottweiler': 2,
#          'Collie Smooth': 25,
#          'Irish Terrier Mix': 21,
#          'St. Bernard Rough Coat/Boxer': 14,
#          'Alaskan Husky/Border Collie': 3,
#          'Pit Bull/Rottweiler': 3,
#          'Cairn Terrier/Scottish Terrier': 2,
#          'Wirehaired Pointing Griffon': 4,
#          'Australian Shepherd/Greyhound': 1,
#          'Labrador Retriever/Collie Smooth': 10,
#          'Boxer/Plott Hound': 4,
#          'Chihuahua Longhair/Dachshund': 15,
#          'Great Dane/Dalmatian': 2,
#          'Jack Russell Terrier/Pug': 3,
#          'Samoyed Mix': 13,
#          'Catahoula/Labrador Retriever': 47,
#          'Miniature Pinscher/Pug': 4,
#          'Labrador Retriever/Queensland Heeler': 11,
#          'Boxer/Pointer': 10,
#          'Basenji/Chihuahua Shorthair': 7,
#          'Greyhound Mix': 41,
#          'Dachshund/Jack Russell Terrier': 6,
#          'Mastiff/Plott Hound': 1,
#          'Picardy Sheepdog': 2,
#          'Dachshund/Parson Russell Terrier': 5,
#          'Staffordshire/Blue Lacy': 2,
#          'Labrador Retriever/Doberman Pinsch': 20,
#          'Mastiff/Chinese Sharpei': 7,
#          'German Shepherd/Alaskan Malamute': 6,
#          'Yorkshire Terrier/Chihuahua Shorthair': 35,
#          'Rat Terrier/Dachshund': 11,
#          'Leonberger Mix': 17,
#          'Rhod Ridgeback/German Shepherd': 5,
#          'Chihuahua Shorthair/Swedish Vallhund': 6,
#          'Great Pyrenees/Catahoula': 9,
#          'Chihuahua Longhair/Maltese': 5,
#          'Chihuahua Shorthair/Basset Hound': 3,
#          'Affenpinscher Mix': 7,
#          'Labrador Retriever/Chesa Bay Retr': 5,
#          'Norwich Terrier Mix': 60,
#          'Bull Terrier Miniature/Chihuahua Shorthair': 1,
#          'Mastiff/Great Dane': 3,
#          'Bloodhound/Labrador Retriever': 2,
#          'Dalmatian/Labrador Retriever': 10,
#          'Bearded Collie Mix': 12,
#          'Chow Chow/Golden Retriever': 5,
#          'Dachshund/Harrier': 2,
#          'Dachshund/Pug': 9,
#          'Anatol Shepherd/Akita': 2,
#          'Lhasa Apso/Havanese': 1,
#          'Australian Shepherd/Field Spaniel': 1,
#          'Australian Cattle Dog/Cairn Terrier': 3,
#          'Flat Coat Retriever/Papillon': 6,
#          'German Shepherd/Pembroke Welsh Corgi': 5,
#          'Akbash': 1,
#          'Chihuahua Longhair/Pekingese': 3,
#          'Greater Swiss Mountain Dog Mix': 5,
#          'Cardigan Welsh Corgi/German Shepherd': 6,
#          'Neapolitan Mastiff Mix': 8,
#          'Treeing Walker Coonhound/Great Dane': 2,
#          'Rhod Ridgeback/Vizsla': 1,
#          'Border Collie/Boxer': 5,
#          'Maltese/Yorkshire Terrier': 17,
#          'German Shorthair Pointer/Brittany': 1,
#          'Dachshund Wirehair/Chihuahua Longhair': 2,
#          'Great Pyrenees/Plott Hound': 2,
#          'Havanese/Miniature Poodle': 4,
#          'Miniature Schnauzer/Cairn Terrier': 9,
#          'Chihuahua Shorthair/German Shepherd': 5,
#          'Boston Terrier/Chihuahua Shorthair': 15,
#          'Border Collie/Siberian Husky': 4,
#          'Border Collie/Shetland Sheepdog': 1,
#          'Queensland Heeler/Labrador Retriever': 4,
#          'Toy Poodle/Yorkshire Terrier': 2,
#          'Border Collie/Standard Schnauzer': 2,
#          'Labrador Retriever/Treeing Walker Coonhound': 5,
#          'Landseer/English Setter': 2,
#          'Alaskan Malamute/Border Collie': 3,
#          'Miniature Poodle/Yorkshire Terrier': 8,
#          'Chihuahua Shorthair/Bichon Frise': 1,
#          'Black Mouth Cur/American Staffordshire Terrier': 1,
#          'Pekingese/Cavalier Span': 1,
#          'Boykin Span Mix': 11,
#          'Rhod Ridgeback/Black Mouth Cur': 2,
#          'Pekingese/Shih Tzu': 4,
#          'Shih Tzu/Pomeranian': 2,
#          'Bichon Frise/Lhasa Apso': 1,
#          'English Coonhound/German Shepherd': 5,
#          'Australian Cattle Dog/Great Pyrenees': 8,
#          'Shih Tzu/Bruss Griffon': 2,
#          'English Foxhound': 6,
#          'Golden Retriever': 64,
#          'Vizsla/Golden Retriever': 2,
#          'Australian Kelpie/Pit Bull': 9,
#          'Black Mouth Cur/Boxer': 5,
#          'Border Terrier/Yorkshire Terrier': 9,
#          'Beagle/Pointer': 7,
#          'Vizsla/Greyhound': 1,
#          'Great Pyrenees/Alaskan Husky': 1,
#          'Pointer/American Bulldog': 2,
#          'Chinese Crested Mix': 14,
#          'Labrador Retriever/Whippet': 17,
#          'Labrador Retriever/Chihuahua Shorthair': 5,
#          'Carolina Dog/Pit Bull': 4,
#          'Australian Kelpie/German Shepherd': 5,
#          'Labrador Retriever/Standard Schnauzer': 13,
#          'Jack Russell Terrier/Boston Terrier': 5,
#          'Lhasa Apso': 46,
#          'Labrador Retriever/Pembroke Welsh Corgi': 2,
#          'Chihuahua Shorthair/Italian Greyhound': 18,
#          'Collie Rough/Golden Retriever': 1,
#          'Great Dane/Labrador Retriever': 21,
#          'Weimaraner': 15,
#          'Chihuahua Shorthair/Manchester Terrier': 10,
#          'Blue Lacy/American Staffordshire Terrier': 1,
#          'Chinese Sharpei/German Shepherd': 3,
#          'Siberian Husky/Labrador Retriever': 33,
#          'Labrador Retriever/Dalmatian': 6,
#          'German Shepherd/Chihuahua Shorthair': 4,
#          'English Bulldog/Cairn Terrier': 1,
#          'Toy Fox Terrier/Yorkshire Terrier': 1,
#          'Golden Retriever/Brittany': 1,
#          'Queensland Heeler/Pit Bull': 5,
#          'Australian Shepherd/Great Pyrenees': 11,
#          'Rhod Ridgeback/Pit Bull': 3,
#          'Cane Corso/Blue Lacy': 3,
#          'Rat Terrier/Boston Terrier': 6,
#          'Cardigan Welsh Corgi/Cairn Terrier': 1,
#          'Treeing Cur Mix': 20,
#          'Jack Russell Terrier/Beagle': 27,
#          'Lhasa Apso/Cocker Spaniel': 2,
#          'Shih Tzu/Cocker Spaniel': 3,
#          'Treeing Walker Coonhound': 3,
#          'Field Spaniel/Cocker Spaniel': 2,
#          'Australian Kelpie/Golden Retriever': 2,
#          'Labrador Retriever/Plott Hound': 40,
#          'Chinese Sharpei/Pit Bull': 7,
#          'Mastiff/American Pit Bull Terrier': 3,
#          'Cardigan Welsh Corgi/Jack Russell Terrier': 3,
#          'Australian Cattle Dog/Australian Shepherd': 11,
#          'Beagle/Boxer': 13,
#          'Australian Cattle Dog/Queensland Heeler': 4,
#          'Dogue De Bordeaux/American Pit Bull Terrier': 1,
#          'Pit Bull/Bull Terrier': 4,
#          'Jack Russell Terrier/Dachshund Wirehair': 2,
#          'Basset Hound/English Pointer': 1,
#          'Border Collie/Mastiff': 2,
#          'Labrador Retriever/Great Dane': 22,
#          'Yorkshire Terrier/Rat Terrier': 7,
#          'West Highland/Toy Fox Terrier': 2,
#          'English Coonhound': 7,
#          'Brittany/Chihuahua Shorthair': 1,
#          'German Shepherd/Finnish Spitz': 1,
#          'German Shepherd/Whippet': 2,
#          'Jack Russell Terrier/Dachshund': 16,
#          'Pit Bull/Jindo': 1,
#          'Dachshund Longhair/Cardigan Welsh Corgi': 3,
#          'Rottweiler/Boxer': 1,
#          'St. Bernard Smooth Coat/Anatol Shepherd': 2,
#          'Miniature Poodle/Cairn Terrier': 7,
#          'American Bulldog/Labrador Retriever': 13,
#          'Newfoundland Mix': 10,
#          'Australian Kelpie/Whippet': 3,
#          'Blue Lacy/American Bulldog': 6,
#          'Akita': 22,
#          'Boxer/Bulldog': 2,
#          'Rhod Ridgeback': 21,
#          'Catahoula/American Bulldog': 2,
#          'Dachshund/Miniature Pinscher': 12,
#          'Labrador Retriever/Pug': 4,
#          'Labrador Retriever/Smooth Fox Terrier': 2,
#          'Unknown': 3,
#          'Australian Cattle Dog/Basenji': 5,
#          'Dutch Shepherd/Plott Hound': 2,
#          'Labrador Retriever/Standard Poodle': 15,
#          'Skye Terrier': 2,
#          'Plott Hound/Blue Lacy': 4,
#          'Bernese Mountain Dog/Rottweiler': 1,
#          'Australian Cattle Dog/Bloodhound': 3,
#          'Toy Poodle/Miniature Schnauzer': 3,
#          'Australian Shepherd/Boxer': 3,
#          'Clumber Spaniel/American Eskimo': 1,
#          'Collie Smooth/German Shepherd': 4,
#          'Cocker Spaniel/Australian Terrier': 3,
#          'Shih Tzu/Maltese': 15,
#          'Akita/Australian Cattle Dog': 6,
#          'French Bulldog/Miniature Poodle': 5,
#          'Cairn Terrier/Miniature Schnauzer': 7,
#          'Greyhound/Airedale Terrier': 1,
#          'Manchester Terrier/Norfolk Terrier': 4,
#          'Alaskan Malamute/Labrador Retriever': 2,
#          'Miniature Poodle/Dachshund': 8,
#          'Bruss Griffon': 9,
#          'Bulldog/Pit Bull': 4,
#          'Jack Russell Terrier/Cairn Terrier': 6,
#          'Border Collie/Miniature Pinscher': 1,
#          'Norfolk Terrier/Pug': 1,
#          'Shih Tzu/Dachshund': 4,
#          'Pembroke Welsh Corgi/Chihuahua Shorthair': 9,
#          'Dachshund/Australian Kelpie': 2,
#          'Great Dane/Catahoula': 1,
#          'Golden Retriever/Australian Shepherd': 2,
#          'Swedish Vallhund Mix': 17,
#          'Border Collie/Staffordshire': 1,
#          'Wire Hair Fox Terrier/Standard Schnauzer': 1,
#          'Pharaoh Hound': 13,
#          'Boxer/Doberman Pinsch': 1,
#          'Border Collie/Australian Kelpie': 2,
#          'Border Collie/Jack Russell Terrier': 2,
#          'Bernese Mountain Dog Mix': 30,
#          'English Pointer': 4,
#          'Dachshund/Australian Cattle Dog': 8,
#          'Anatol Shepherd/Pit Bull': 2,
#          'Yorkshire Terrier/Dachshund': 1,
#          'Chihuahua Shorthair/Pembroke Welsh Corgi': 9,
#          'Beagle/Jack Russell Terrier': 5,
#          'Pekingese/Catahoula': 1,
#          'Dachshund/Miniature Poodle': 4,
#          'Border Collie/Catahoula': 11,
#          'Doberman Pinsch/Black Mouth Cur': 3,
#          'Miniature Schnauzer/Shih Tzu': 2,
#          'Mexican Hairless/Chihuahua Shorthair': 1,
#          'Chinese Sharpei/Basset Hound': 1,
#          'Yorkshire Terrier/Miniature Schnauzer': 19,
#          'German Wirehaired Pointer': 4,
#          'Rat Terrier/Australian Cattle Dog': 2,
#          'Australian Shepherd/Feist': 1,
#          'Maltese/Border Collie': 1,
#          'Newfoundland/Labrador Retriever': 4,
#          'Mexican Hairless Mix': 8,
#          'Bruss Griffon/Dachshund': 2,
#          'Vizsla/Catahoula': 1,
#          'German Shepherd/Anatol Shepherd': 16,
#          'English Setter Mix': 8,
#          'Canaan Dog/Pit Bull': 1,
#          'Yorkshire Terrier/Chihuahua Longhair': 17,
#          'Pointer/Chihuahua Longhair': 6,
#          'Anatol Shepherd/German Shepherd': 21,
#          'Pit Bull/Bulldog': 7,
#          'Chow Chow/Siberian Husky': 5,
#          'Miniature Schnauzer/Australian Cattle Dog': 2,
#          'Dachshund/Catahoula': 4,
#          'Anatol Shepherd/American Bulldog': 1,
#          'Queensland Heeler/German Shepherd': 2,
#          'Basset Hound/Cardigan Welsh Corgi': 2,
#          'Belgian Malinois/Labrador Retriever': 4,
#          'Queensland Heeler/Border Collie': 1,
#          'Vizsla/Labrador Retriever': 6,
#          'Rat Terrier/Pembroke Welsh Corgi': 2,
#          'Australian Cattle Dog/Catahoula': 11,
#          'Chihuahua Longhair/Papillon': 3,
#          'Yorkshire Terrier/Maltese': 14,
#          'Pointer/Australian Kelpie': 1,
#          'Dachshund Longhair/Chihuahua Shorthair': 10,
#          'Pointer/Boxer': 10,
#          'Border Collie/Chow Chow': 9,
#          'Sussex Span Mix': 2,
#          'Catahoula/Whippet': 5,
#          'Tibetan Spaniel': 7,
#          'Labrador Retriever/German Shorthair Pointer': 4,
#          'Great Dane/Boerboel': 1,
#          'Chow Chow/Australian Cattle Dog': 8,
#          'Miniature Schnauzer/Toy Poodle': 5,
#          'Dachshund Longhair/Australian Cattle Dog': 1,
#          'Australian Cattle Dog/Staffordshire': 13,
#          'Smooth Fox Terrier/Cardigan Welsh Corgi': 2,
#          'Pit Bull/Mastiff': 7,
#          'Chinese Sharpei/Border Collie': 2,
#          'Anatol Shepherd/Black Mouth Cur': 2,
#          'Maltese/Toy Poodle': 18,
#          'Pit Bull/Border Collie': 21,
#          'Dogo Argentino/Boxer': 1,
#          'Whippet/Labrador Retriever': 7,
#          'Australian Cattle Dog/Chow Chow': 5,
#          'Manchester Terrier/Pembroke Welsh Corgi': 2,
#          'Plott Hound/Mastiff': 2,
#          'Pug/Miniature Schnauzer': 1,
#          'Golden Retriever/Beagle': 4,
#          'Treeing Tennesse Brindle': 4,
#          'Pit Bull/Rhod Ridgeback': 3,
#          'Beagle/German Shorthair Pointer': 1,
#          'Chihuahua Shorthair/Border Terrier': 10,
#          'Neapolitan Mastiff': 3,
#          'Border Collie/Akita': 5,
#          'Queensland Heeler/Chihuahua Shorthair': 4,
#          'Greyhound/Pointer': 1,
#          'Schnauzer Giant': 3,
#          'Australian Kelpie/Miniature Pinscher': 4,
#          'Miniature Poodle/Lhasa Apso': 18,
#          'Labrador Retriever/American Bulldog': 8,
#          'Basset Hound/Chinese Sharpei': 5,
#          'Chow Chow/German Shepherd': 18,
#          'Chihuahua Shorthair/Chinese Sharpei': 2,
#          'Treeing Walker Coonhound/Labrador Retriever': 2,
#          'Boxer/Australian Cattle Dog': 10,
#          'Border Collie/Brittany': 1,
#          'Collie Rough/Pointer': 1,
#          'Catahoula/Chow Chow': 1,
#          'Whippet/Chihuahua Shorthair': 4,
#          'Dachshund Wirehair/Chihuahua Shorthair': 18,
#          'German Pinscher/Whippet': 1,
#          'Blue Lacy/Staffordshire': 1,
#          'Australian Shepherd/Nova Scotia Duck Tolling Retriever': 2,
#          'Briard': 1,
#          'Bernese Mountain Dog': 6,
#          'Chihuahua Shorthair/Staffordshire': 1,
#          'Blue Lacy/Australian Kelpie': 3,
#          'German Shepherd/Australian Shepherd': 14,
#          'Old English Bulldog Mix': 13,
#          'Dandie Dinmont/Miniature Poodle': 1,
#          'Basset Hound/Blue Lacy': 1,
#          'Yorkshire Terrier/Standard Poodle': 3,
#          'Beagle/Black Mouth Cur': 6,
#          'Labrador Retriever/Staffordshire': 12,
#          'Akita/Siberian Husky': 4,
#          'Manchester Terrier/Dachshund': 7,
#          'Shih Tzu/Havanese': 4,
#          'Australian Shepherd/Pembroke Welsh Corgi': 3,
#          'Chihuahua Shorthair/Shih Tzu': 4,
#          'Canaan Dog Mix': 10,
#          'Border Collie/Border Collie': 2,
#          'Great Dane/Anatol Shepherd': 2,
#          'Australian Cattle Dog/Golden Retriever': 1,
#          'Chihuahua Shorthair/Miniature Schnauzer': 6,
#          'Australian Cattle Dog/Dachshund': 6,
#          'Black Mouth Cur/Anatol Shepherd': 2,
#          ...})
